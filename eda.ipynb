# %%
## Group work

# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\ginny\\Desktop\\RCG\\Group Work\\Iowa_Liquor_Sales_SEP2024.csv") #Maud
# Out:
# C:\Users\ginny\AppData\Local\Temp\ipykernel_17340\2597783145.py:4: DtypeWarning: Columns (6,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("C:\\Users\\ginny\\Desktop\\RCG\\Group Work\\Iowa_Liquor_Sales_SEP2024.csv")

# %%
data.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0        S03408100057  01/03/2012          3162
# 1        S03408800027  01/03/2012          2959
# 2        S03382600002  01/03/2012          4317
# 3        S03411200041  01/03/2012          2587
# 4        S03410100024  01/03/2012          3962
#
#                          Store Name              Address        City Zip Code  \
# 0       NASH FINCH / WHOLESALE FOOD        807 GRANDVIEW   MUSCATINE    52761
# 1                DAHL'S / MERLE HAY  4343 MERLE HAY ROAD  DES MOINES    50310
# 2  FAREWAY STORES #941 / GREENFIELD          212 SW KENT  GREENFIELD    50849
# 3      HY-VEE FOOD STORE / JOHNSTON  5750 MERLE HAY ROAD    JOHNSTON    50131
# 4        DURANT STREET COUNTRY STOP        618 DURANT ST      HARLAN    51537
#
#                          Store Location  County Number     County  ...  \
# 0  POINT (-91.06411300000002 41.408437)           70.0  MUSCATINE  ...
# ...
